# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Ozgur SANLI Data Scientist**

# %% [markdown]
# *I am interesting in Data Science because i like to solve puzzles*

# %% [markdown]
# # This code prints even numbers from 0 to 10

# %%
even=[i for i in range(10) if i%2==0]
print(even)
# Out:
# [0, 2, 4, 6, 8]

# %% [markdown]
# 1. Numbered list
# 2. Numbered list

# %% [markdown]
# - Bulleted List
# - Bulleted List

# %% [markdown]
# [google.com](http://google.com)
